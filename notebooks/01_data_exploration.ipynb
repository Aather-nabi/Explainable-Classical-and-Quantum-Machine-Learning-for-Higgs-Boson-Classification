# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


plt.style.use('default')
pd.set_option('display.max_columns', None)

# %% [markdown]
# # load dataset

# %%
try:
    df = pd.read_csv(
        "../data/atlas-higgs-challenge-2014-v2.csv.gz"
    )
    print("Data loaded successfully.")
    print(df.shape)
    df.head()
#except FileNotFoundError:
   # print("File not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data loaded successfully.
# (818238, 35)

# %%
print(columns := df.columns.tolist())
# Out:
# ['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt', 'Weight', 'Label', 'KaggleSet', 'KaggleWeight']

# %%
# dataset overview
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 818238
# Columns: 35

# %%
# dataset info/ data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818238 entries, 0 to 818237
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      818238 non-null  int64
#  1   DER_mass_MMC                 818238 non-null  float64
#  2   DER_mass_transverse_met_lep  818238 non-null  float64
#  3   DER_mass_vis                 818238 non-null  float64
#  4   DER_pt_h                     818238 non-null  float64
#  5   DER_deltaeta_jet_jet         818238 non-null  float64
#  6   DER_mass_jet_jet             818238 non-null  float64
#  7   DER_prodeta_jet_jet          818238 non-null  float64
#  8   DER_deltar_tau_lep           818238 non-null  float64
#  9   DER_pt_tot                   818238 non-null  float64
#  10  DER_sum_pt                   818238 non-null  float64
#  11  DER_pt_ratio_lep_tau         818238 non-null  float64
# ...

# %%
# dataset statistics / summary
df.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  818238.000000  818238.000000                818238.000000
# mean   509118.500000     -48.819019                    49.252714
# std    236205.109118     406.118397                    35.378609
# min    100000.000000    -999.000000                     0.000000
# 25%    304559.250000      78.166000                    19.304000
# 50%    509118.500000     105.061000                    46.484000
# 75%    713677.750000     130.730000                    73.620000
# max    918237.000000    1949.261000                   968.669000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  818238.000000  818238.000000         818238.000000     818238.000000
# mean       81.140561      57.849524           -707.740880       -600.191191
# std        40.582708      63.411938            454.793899        658.724040
# ...

# %% [markdown]
# ## missing value analaysis

# %%
# Check for missing values (NAN)
df.isnull().sum()
# Out:
# EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# DER_lep_eta_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_subleading_pt          0
# ...

# %%
# Check if there are any missing values at all
df.isnull().values.any()
# Out:
# np.False_

# %%
# Check for missing values represented as -999
(df == -999).sum()
# Out:
# EventId                             0
# DER_mass_MMC                   124602
# DER_mass_transverse_met_lep         0
# DER_mass_vis                        0
# DER_pt_h                            0
# DER_deltaeta_jet_jet           580253
# DER_mass_jet_jet               580253
# DER_prodeta_jet_jet            580253
# DER_deltar_tau_lep                  0
# DER_pt_tot                          0
# DER_sum_pt                          0
# DER_pt_ratio_lep_tau                0
# DER_met_phi_centrality              0
# DER_lep_eta_centrality         580253
# PRI_tau_pt                          0
# PRI_tau_eta                         0
# PRI_tau_phi                         0
# PRI_lep_pt                          0
# PRI_lep_eta                         0
# PRI_lep_phi                         0
# PRI_met                             0
# PRI_met_phi                         0
# PRI_met_sumet                       0
# PRI_jet_num                         0
# PRI_jet_leading_pt             327371
# ...

# %%
# check total number of -999 values in the entire dataframe
(df == -999).sum().sum()
# Out:
# np.int64(5168486)

# %%
# Check for missing values represented as -999 and sort by count
missing_counts = (df == -999).sum()

missing_counts = missing_counts[
    missing_counts > 0
].sort_values(ascending=False)

missing_counts
# Out:
# DER_deltaeta_jet_jet      580253
# DER_mass_jet_jet          580253
# DER_prodeta_jet_jet       580253
# PRI_jet_subleading_phi    580253
# DER_lep_eta_centrality    580253
# PRI_jet_subleading_eta    580253
# PRI_jet_subleading_pt     580253
# PRI_jet_leading_eta       327371
# PRI_jet_leading_pt        327371
# PRI_jet_leading_phi       327371
# DER_mass_MMC              124602
# dtype: int64

# %%
# percentage of missing values in each column
missing_percent = (
    missing_counts / len(df)
) * 100

missing_percent
# Out:
# DER_deltaeta_jet_jet      70.914942
# DER_mass_jet_jet          70.914942
# DER_prodeta_jet_jet       70.914942
# PRI_jet_subleading_phi    70.914942
# DER_lep_eta_centrality    70.914942
# PRI_jet_subleading_eta    70.914942
# PRI_jet_subleading_pt     70.914942
# PRI_jet_leading_eta       40.009264
# PRI_jet_leading_pt        40.009264
# PRI_jet_leading_phi       40.009264
# DER_mass_MMC              15.228088
# dtype: float64

# %% [markdown]
# # Visualization

# %%
# Visualize missing values percentage
plt.figure(figsize=(12,6))

missing_percent.plot(kind='bar')
plt.title("Missing Values (%)")
plt.ylabel("Percentage")

plt.tight_layout()


plt.savefig(
    "../results/plots/missing_values.png",
    dpi=300
)

plt.show()

# %% [markdown]
# # Target Variable Analysis

# %%
# Class distribution
df['Label'].value_counts()
# Out:
# Label
# b    538678
# s    279560
# Name: count, dtype: int64

# %%
# Class distribution in percentage
df['Label'].value_counts(normalize=True)*100
# Out:
# Label
# b    65.833902
# s    34.166098
# Name: proportion, dtype: float64

# %%
# Visualize class distribution
plt.figure(figsize=(6,4))

sns.countplot(
    x='Label',
    data=df,
    palette={'b': 'red', 's': 'blue'}
)

plt.title("Signal vs Background")

plt.savefig(
    "../results/plots/class_distribution.png",
    bbox_inches="tight",
    dpi=300
)

plt.show()
# Out:
# C:\Users\nabia\AppData\Local\Temp\ipykernel_27028\819277435.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# # Event Weights Analysis

# %%
df['Weight'].describe()
# Out:
# count    818238.000000
# mean          0.503144
# std           0.572200
# min           0.000461
# 25%           0.005721
# 50%           0.357223
# 75%           0.733462
# max           2.386316
# Name: Weight, dtype: float64

# %%
# Visualize weight distribution
plt.figure(figsize=(10,6))

sns.histplot(
    df['Weight'],
    bins=50
)

plt.title("Event Weight Distribution")


plt.savefig(
    "../results/plots/weight_distribution.png"
)
plt.show()

# %% [markdown]
# # Feature Distribution

# %%
# List of feature columns (excluding target and ID columns)
features = [
    col
    for col in df.columns
    if col not in ['EventId','Weight','Label','KaggleSet','kaggle_weight']
]

# %%
# Visualize feature distributions
df[features].hist(
    figsize=(20,20),
    bins=50
)

plt.tight_layout()


plt.savefig(
    "../results/plots/feature_distributions.png"                                        
)
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
# Correlation analysis (after replacing -999 with NaN)
df_corr = df.replace(-999, np.nan)

# %%
# Compute correlation matrix (only for numeric features)
corr = df_corr.corr(
    numeric_only=True
)

# %%
# Visualize correlation matrix(heatmap)
plt.figure(
    figsize=(18,12)
)

sns.heatmap(
    corr,
    annot=True,      # Show correlation values
    fmt=".2f",
    cmap='coolwarm',
    center=0,
    linewidths=0.5
)

plt.title("Correlation Matrix")


plt.savefig(
    "../results/plots/correlation_matrix.png"
)
plt.show()

# %% [markdown]
# # Outlier Detection

# %%
# Boxplots for a sample of features to check for outliers
sample_features = features[:10]

for feature in sample_features:

    plt.figure(figsize=(8,2))

    sns.boxplot(
        x=df[feature]
    )

    plt.title(feature)


    plt.savefig(
        f"../results/plots/outliers_detection/boxplot_{feature}.png"
    )
    plt.show()

# %% [markdown]
# ### Feature Relationship with Target

# %%
# convert label to numeric

df_temp = df.copy()

df_temp['Label'] = (
    df_temp['Label']
    .map({'b':0,'s':1})
)

# %%
# Class-wise feature means (after replacing -999 with NaN)
class_means = (
    df_temp.groupby('Label').mean(numeric_only=True)
)

class_means.head()
# Out:
#              EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# Label
# 0      509271.528401   -118.751324                    58.190607     81.508522
# 1      508823.632948     85.931998                    32.030485     80.431545
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# Label
# 0      48.948308           -754.702945       -691.808361          -755.136588
# 1      75.001081           -617.250712       -423.656086          -619.167649
#
#        DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# Label
# 0                2.367647   19.186305  145.730379              1.556624
# 1                2.385865   18.552087  183.386946              1.211695
#
#        DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  \
# Label
# 0                   -0.361228             -755.079906   34.882100
# 1                    0.323517             -618.181077   46.051219
#
# ...

# %% [markdown]
# ## Key Findings
#
# 1. Dataset contains 818238 samples and 35 features.
#
# 2. Several features contain missing values represented by -999.
#
# 3. Dataset is moderately imbalanced between signal and background classes.
#
# 4. Certain physics variables show strong separation between classes.
#
# 5. Feature distributions exhibit skewness and outliers.
#
# 6. Standardization will be required.
#
# 7. Missing values will be replaced with NaN and imputed using median values.
#
# 8. EventId will be removed from model training.
#
# 9. Weight will not be used as an input feature.
